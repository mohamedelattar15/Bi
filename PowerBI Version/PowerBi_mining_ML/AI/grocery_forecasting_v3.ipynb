# %% [markdown]
# # 🗂️ Grocery Revenue Forecasting — Tableau de Bord
# ## Organisation modulaire des notebooks
#
# Ce notebook est un **tableau de bord** qui référence tous les notebooks organisés dans `models/`.
# Chaque modèle est dans son propre notebook pour une meilleure séparation des responsabilités.
#
# ---
#
# ### 📂 Structure du projet
#
# ```
# Power_BI/AI/
# ├── daily_revenue.csv              ← Données brutes journalières
# ├── grocery_forecasting_v3.ipynb   ← Ce tableau de bord
# │
# └── models/                        ← Notebooks modulaires
#     ├── 00_Preprocessing.ipynb     ← Chargement, COVID, Feature Engineering, Split, Métriques
#     ├── 01_SARIMA.ipynb            ← Auto-SARIMA (Grid Search des ordres)
#     ├── 02_HoltWinters.ipynb       ← Holt-Winters (4 configurations)
#     ├── 03_XGBoost.ipynb           ← XGBoost (Grid Search + Feature Importance)
#     ├── 04_Prophet.ipynb           ← Prophet (COVID comme Holiday, paramètres corrigés)
#     ├── 05_Ensemble_Comparaison.ipynb ← Ensemble pondéré + Diebold-Mariano
#     └── 06_Forecast_2023.ipynb     ← Prévision 2023 avec Bootstrap IC
# ```
#
# ---
#
# ### 🔄 Workflow d'exécution
#
# ```mermaid
# graph LR
#     A[00_Preprocessing] --> B[01_SARIMA]
#     A --> C[02_HoltWinters]
#     A --> D[03_XGBoost]
#     A --> E[04_Prophet]
#     B --> F[05_Ensemble_Comparaison]
#     C --> F
#     D --> F
#     E --> F
#     A --> G[06_Forecast_2023]
#     F --> G
# ```
#
# ---
#
# ### 📊 Résultats des modèles
#
# | Modèle | MAPE | R² | Notebook |
# |--------|------|----|----------|
# | SARIMA | ? | ? | `01_SARIMA.ipynb` |
# | Holt-Winters | ? | ? | `02_HoltWinters.ipynb` |
# | XGBoost | ? | ? | `03_XGBoost.ipynb` |
# | Prophet | ? | ? | `04_Prophet.ipynb` |
# | **Ensemble** | **?** | **?** | `05_Ensemble_Comparaison.ipynb` |
#
# > ℹ️ Exécutez les notebooks dans l'ordre pour voir les résultats.
